# %%
from src import func1 as f1
import importlib

# %%
importlib.reload(f1)
# Out:
# <module 'src.func1' from 'C:\\Users\\kcall\\OneDrive - Gainwell Technologies\\Documents\\Underserved_otp\\src\\func1.py'>

# %%
zip_geo_data = f1.load_zip_geo_data()
provider_data = f1.load_provider_data()
year_rates_data = f1.load_rates_data()
states_geo_data = f1.load_states_geo_data()
# Out:
# c:\Users\kcall\OneDrive - Gainwell Technologies\Documents\Underserved_otp\src\func1.py:175: DtypeWarning: Columns (12,13,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   rates_data = pd.read_csv('data/prescribing_rates.csv')

# %%
f1.plot_rates(states_geo_data, zip_geo_data, year_rates_data, 'Utah')

# %%
f1.plot_rates(states_geo_data, zip_geo_data, year_rates_data, 'Utah')

# %%
f1.plot_providers(states_geo_data, zip_geo_data, provider_data, 'Utah')

# %%
f1.plot_dist_to_providers(zip_geo_data, states_geo_data, provider_data, 'Ohio')
# Out:
# 7728    33910.009349
# 7729    29532.989794
# 7730    25521.797392
# 7731    20821.505563
# 7732     7426.116158
#             ...
# 8956    27860.481601
# 8957    32301.562867
# 8958    18430.581446
# 8959    16222.684817
# 8960    13174.691149
# Name: dist_to_provider, Length: 1233, dtype: float64
# 21.268998861312866

# %%
f1.plot_dist_to_providers(zip_geo_data, states_geo_data, provider_data, 'Florida')
# Out:
# 2847     4913.541110
# 2848    13982.553200
# 2849    14381.744826
# 2850        0.000000
# 2851        0.000000
#             ...
# 6081    71110.610507
# 6082    35628.724504
# 6083    60925.031834
# 6084    51632.886638
# 6085    50012.158354
# Name: dist_to_provider, Length: 1013, dtype: float64
# 18.315038919448853
